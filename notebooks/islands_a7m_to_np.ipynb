# %%
import os
import glob
import zlib
import pathlib
import tempfile
import subprocess
import numpy as np

from binascii import unhexlify
from xml.etree import ElementTree
from struct import unpack

# %%
# island_glob = os.path.join("..", "resources", "data", "base", "provinces", "roman", "islands", "pool", "**", "*.a7m")
island_glob = os.path.join("..", "resources", "1800", "data", "sessions", "islands", "pool", "moderate", "**", "*.a7m")
# island_glob = os.path.join("..", "resources", "1800", "data", "sessions", "islands", "pool", "moderate", "moderate_l_01", "*.a7m")
output_dir = os.path.join("..", "resources", "islands")
reader_path = os.path.join("..", "lib", "FileDBReader", "FileDBReader.exe")

# %%
def enumerate_bits(byte):
    for i in range(8):
        yield byte >> i & 1


import matplotlib.pyplot as plt

def read_grids(xmlpath):
    data = ElementTree.parse(xmlpath)
    node = data.getroot()

    # Estimate the islands with river by calculating how many river tiles block land tiles.
    # The result will slightly underestimate land area because we subtract coast river tiles.

    res = node.find(".//Water")
    width = unpack("I", unhexlify(res.find("x").text))[0]
    height = unpack("I", unhexlify(res.find("y").text))[0]
    water = unhexlify(res.find("bits").text)
    water = np.array([bit for byte in water for bit in enumerate_bits(byte)], dtype=float)
    water = water.reshape(width, height)
    water[water == 0] = np.nan

    res = node.find(".//AreaIDs")
    width = unpack("I", unhexlify(res.find("x").text))[0]
    height = unpack("I", unhexlify(res.find("y").text))[0]
    area = unhexlify(res.find("val").text)
    area = np.array(unpack(f"{len(area) // 2}h", area), dtype=float)
    area = area.reshape(width, height)
    area[area != 8193] = np.nan  # Keep only the buildable area.
    area[area == 8193] = 1

    res = node.find(".//RiverGrid")
    width = unpack("I", unhexlify(res.find("x").text))[0]
    height = unpack("I", unhexlify(res.find("y").text))[0]
    river = unhexlify(res.find("bits").text)
    river = np.array([bit for byte in river for bit in enumerate_bits(byte)], dtype=float)
    river = river.reshape(width, height)
    river[river != 0] = np.nan
    river[river == 0] = 1

    return area, water, river

# %%
def a7m_to_xml(data_compressed):
    decompressed = zlib.decompress(data_compressed)
    with tempfile.TemporaryDirectory() as tmp:
        decompressed_path = os.path.join(tmp, "data.a7m")
        with open(decompressed_path, "wb") as f:
            f.write(decompressed)
        read_cmd = [reader_path, "decompress", "-f", decompressed_path]
        read_process = subprocess.Popen(read_cmd)
        read_return_code = read_process.wait()
        if read_return_code != 0:
            raise Exception(read_return_code)
        xml_path = os.path.join(tmp, "data.xml")
        area, water, river = read_grids(xml_path)
    return area, water, river

# %%
def read_island(island_path):
	with open(island_path, "rb") as f:
		f.seek(0x310)
		offset = unpack("Q", f.read(8))[0]
		size = offset - 0x318
		payload = f.read(size)
	return payload

# %%
for input_path in glob.glob(island_glob):
    island_name = pathlib.Path(input_path).stem
    output_path = os.path.join(output_dir, island_name + ".npy")
    
    print(f"Converting {input_path} \u2192 {output_path}", end="")
    island_data = read_island(input_path)
    area, water, river = a7m_to_xml(island_data)

    buildable = (area == 1) & (water == 1)
    np.save(output_path, buildable)
    print(" \u2713")
# Out:
# Converting ..\resources\1800\data\sessions\islands\pool\moderate
river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_09\moderate_l_09.a7m → ..\resources\islands\moderate_l_09.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_09\moderate_l_09_river_01.a7m → ..\resources\islands\moderate_l_09_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_10\moderate_l_10.a7m → ..\resources\islands\moderate_l_10.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_10\moderate_l_10_river_01.a7m → ..\resources\islands\moderate_l_10_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_11\moderate_l_11.a7m → ..\resources\islands\moderate_l_11.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_11\moderate_l_11_river_01.a7m → ..\resources\islands\moderate_l_11_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_12\moderate_l_12.a7m → ..\resources\islands\moderate_l_12.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_12\moderate_l_12_river_01.a7m → ..\resources\islands\moderate_l_12_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_13\moderate_l_13.a7m → ..\resources\islands\moderate_l_13.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_13\moderate_l_13_river_01.a7m → ..\resources\islands\moderate_l_13_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_14\moderate_l_14.a7m → ..\resources\islands\moderate_l_14.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_l_14\moderate_l_14_river_01.a7m → ..\resources\islands\moderate_l_14_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_01\moderate_m_01.a7m → ..\resources\islands\moderate_m_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_01\moderate_m_01_river_01.a7m → ..\resources\islands\moderate_m_01_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_02\moderate_m_02.a7m → ..\resources\islands\moderate_m_02.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_02\moderate_m_02_river_01.a7m → ..\resources\islands\moderate_m_02_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_03\moderate_m_03.a7m → ..\resources\islands\moderate_m_03.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_03\moderate_m_03_river_01.a7m → ..\resources\islands\moderate_m_03_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_04\moderate_m_04.a7m → ..\resources\islands\moderate_m_04.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_04\moderate_m_04_river_01.a7m → ..\resources\islands\moderate_m_04_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_05\moderate_m_05.a7m → ..\resources\islands\moderate_m_05.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_05\moderate_m_05_river_01.a7m → ..\resources\islands\moderate_m_05_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_06\moderate_m_06.a7m → ..\resources\islands\moderate_m_06.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_06\moderate_m_06_river_01.a7m → ..\resources\islands\moderate_m_06_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_07\moderate_m_07.a7m → ..\resources\islands\moderate_m_07.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_07\moderate_m_07_river_01.a7m → ..\resources\islands\moderate_m_07_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_08\moderate_m_08.a7m → ..\resources\islands\moderate_m_08.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_08\moderate_m_08_river_01.a7m → ..\resources\islands\moderate_m_08_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_09\moderate_m_09.a7m → ..\resources\islands\moderate_m_09.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_m_09\moderate_m_09_river_01.a7m → ..\resources\islands\moderate_m_09_river_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_s_01\moderate_s_01.a7m → ..\resources\islands\moderate_s_01.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_s_02\moderate_s_02.a7m → ..\resources\islands\moderate_s_02.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_s_03\moderate_s_03.a7m → ..\resources\islands\moderate_s_03.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_s_04\moderate_s_04.a7m → ..\resources\islands\moderate_s_04.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_s_05\moderate_s_05.a7m → ..\resources\islands\moderate_s_05.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_s_06\moderate_s_06.a7m → ..\resources\islands\moderate_s_06.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_s_07\moderate_s_07.a7m → ..\resources\islands\moderate_s_07.npy ✓
# Converting ..\resources\1800\data\sessions\islands\pool\moderate\moderate_s_08\moderate_s_08.a7m → ..\resources\islands\moderate_s_08.npy
